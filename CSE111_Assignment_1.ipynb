# %%
#*********String******
#1
text=input()
a,b=0,0
for x in text:
    if ord(x)>=65 and ord(x)<=90:
        a+=1
    else:
        b+=1
if a>b:
    print(text.upper())
else:
    print(text.lower())
#2
text=input()
num=0
word=0
for x in text:
    if ord(x)>=48 and ord(x)<=57:
        num+=1
    elif ord(x)>=65 and ord(x)<=122:
        word+=1
if num==len(text):
    print('NUMBER')
else:
    if word==len(text):
        print('WORD')
    else:
        print('MIXED')

#3
text=input()
text_1= ''
words=''
for x in range(len(text)):
    if ord(text[x])>=65 and ord(text[x])<=90:
            text_1+= text[x + 1:len(text)]
            break
text_1= text_1[::-1]
for y in range(len(text_1)):
    if ord(text[y])>=65 and ord(text[y])<=90:
        words+= text_1[y + 1:len(text_1)]
        break
if len(words)>1:
    print(words[::-1])
else:
    print('BLANK')
#4
text=input().split(',')
words=''
for x in text[0]:
    if x in text[1]:
        words+=x
for x in text[1]:
    if x in text[0]:
        words+=x
if len(words)>1:
    print(words)
else:
    print('Nothing in common')
#5
text=input()
digit=0
uppercase_character=0
lowercase_character=0
special_charecter=0
for x in text:
    if x=='_' or x=='@' or x=='!' or x=='#' or x=='$':
        special_charecter+=1
    if ord(x)>=48 and ord(x)<=57:
        digit+=1
    if ord(x)>=65 and ord(x)<=90:
        uppercase_character+=1
    if ord(x)>=95 and ord(x)<=122:
        lowercase_character+=1
if special_charecter>=1 and digit>=1 and uppercase_character>=1 and lowercase_character>=1:
    print('OK')
result=''
if digit==0:
    result+='digit missing,'
if uppercase_character==0:
    result+='uppercase character missing,'
if lowercase_character==0:
    result+='lowercase character missing,'
if special_charecter==0:
    result+='Special character missing'
print(result)
#list***********
#1
listx=[]
while True:
    num=input()
    if num!='STOP':
        listx.append(int(num))
    else:
        break
dict={}
for x in listx:
    if x not in dict:
        dict[x]=1
    else:
        dict[x]=dict[x]+1
for a,b in dict.items():
    print(a,'-',b,'times')
#2
test_case=int(input())
listy=[]
for x in range(test_case):
    listx=list(map(int,input().split(' ')))
    listy.append(listx)
listz=[]
dict={}
for y in listy:
    a = 0
    for g in y:
        a+=g
    dict[a]=y
max_value=0
max_list= ''
for m,n in dict.items():
    if m>max_value:
        max_value=m
        max_list=n
print(max_value)
print(max_list)
#3
def UB_Jupmer(List):
    ref_list = [num for num in range(1, len(List))]
    abs_diff = []
    for i in range(len(List) - 1):
        elem = List[i] - List[i + 1]
        elem = abs(elem)
        abs_diff.append(elem)
    if sorted(ref_list) == sorted(abs_diff):
        return True
    else:
        return False
user_input = input()
result = []
while user_input != "STOP":
    List = [int(num) for num in user_input.split()]
    if UB_Jupmer(List):
        result.append("UB Jumper")
    else:
        result.append("Not UB Jumper")
    user_input = input()
for output in result:
    print(output)
#4
#ACM ICPC
#BRACU ACM Chapter
num=input().split(' ')
n=int(num[0])#students
k=int(num[1])#times
coders=list(map(int,input().split(' ')))
team=0
for x in coders:
  if (x+k)<=5:
    team+=1
print(team//3)#3 coders per team


#dict and tuples
#1
dict_input_1=input().split(',')
dict_input_2=input().split(',')
dict_1={}
dict_2={}
for x in dict_input_1:
    text=x.strip().split(':')
    dict_1[text[0]]=int(text[1])
for x in dict_input_2:
    text=x.strip().split(':')
    dict_2[text[0]]=int(text[1])
for i in dict_2.keys():
    if i in dict_1:
        dict_2[i]+=dict_1[i]
    else:
        pass
for m,n in dict_1.items():
    if m not in dict_2:
        dict_2[m]=n
dict_key_sorted=sorted(dict_2.items())
the_dict=(dict(dict_key_sorted))
print(the_dict)
listx=[]
for y in the_dict.values():
    listx.append(y)
listx.sort()
listy=[]
for x in listx:
  if x not in listy:
    listy.append(x)
print('Values:',tuple(listy))
#a: 100, b: 100, c: 200, d: 300
#a: 300, b: 200, d: 400, e: 200




#2
listx=[]
while True:
    num=input()
    if num!='STOP':
        listx.append(int(num))
    else:
        break
dict={}
for x in listx:
    if x not in dict:
        dict[x]=1
    else:
        dict[x]=dict[x]+1
for a,b in dict.items():
    print(a,'-',b,'times')
#3
dict_input_1=input().split(',')
dict_1={}
for x in dict_input_1:
    text=x.strip().split(':')
    dict_1[text[0]]=(text[1])
dict_2={}
for x,y in dict_1.items():
    if y in dict_2:
        dict_2[y]= dict_2[y] + [x]
    else:
        dict_2[y]=[x]
print(dict_2)#key1 : value1, key2 : value2, key3 : value1

#4
#dict & tuple
#4
button_pad={1: '.,?!',2: 'ABC',3: 'DEF',4: 'GHI',5: 'JKL',6: 'MNO',7: 'PQRS',8: 'TUV',9: 'WXYZ',0: ' '}
text = input().upper()
for x in text:
    a=0
    b=0
    for y, z in button_pad.items():
        if x in z:
            b = y
            a = z.index(x) + 1
    print(str(b) * a, end='')
##function***********
#1
def BMI(x,y):
  p=x/100#float
  t=y/(p**2)#float
  l="{:.1f}".format(t)
  r=float(l)
  #p='{:.1f}'.format(w)
  if r<18.5:
    a='Underweight'
  if r>=18.5 and r<=24.9:
    a='Normal'
  if r>=25 and r<=30:
    a='Overweight'
  if r>30:
    a='Obese'
  print(f'Score is {r}. You are {a}')
m=input().split(',')
x=int(m[0])
y=int(m[1])
BMI(x,y)
#2
def math_problem(minimum,maximum,divisor):
  total=0
  for x in range(minimum,maximum):
    if x%divisor==0:
      total+=x
  return total
number=input().split(',')
min=int(number[0])
max=int(number[1])
div=int(number[2])
print(math_problem(min,max,div))
#3
def price(food):
    cost=0
    if food=='BBQ Chicken Cheese Burger':
        cost+=250
    elif food=='Beef Burger':
        cost+=170
    elif food=='Naga Drums':
        cost+=200
    vat=cost*.08
    total_cost=cost+vat+40
    return total_cost
text=input()
print(price(text))
#4
def replace_domain(x,y,z=''):
  s=''
  p=''
  for i in range(len(x)):
    s+=x[i]
    if x[i]=='@':
      break
  p=s+y
  if p!=x:
    print(f'Changed:{p}')
  else:
     print(f'Unchanged:{p}')

replace_domain('bob@sheba.xyz', 'sheba.xyz')
#5
def fun(w):
  n=w[1:len(w)-1]
  p=n.replace(' ','')
  s=n[::-1]
  q=p[::-1]
  if n==s or p==q:
    print('Palindrome')
  else:
    print('Not Palindrome')
w=input()
fun(w)
#6
def sententce_fix(text):
    words = text.strip().split(' ')
    string = ''
    for x in range(len(words)):
        m = words[x]
        n = words[x - 1]
        if x == 0 or '.' in n or '?' in n or '!' in n:
            string += m[0].upper() + m[1:] + ' '
            continue
        if len(m) == 1 and m == 'i':
            string += m.upper() + ' '
            continue
        string += m + ' '
    return  string
sentence=input()
print(sententce_fix(sentence))
